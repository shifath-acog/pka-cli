# %%
import pandas as pd
import subprocess
import os
import shutil

os.chdir('/work')
print("Current Directory:", os.getcwd())

df = pd.read_csv('selected_smiles_solv_pka1.csv')

for index, row in df.iterrows():
    inp_smiles = row['smiles']
    #pKa_EXP = row['exp_pka']
    #dielectric_value = row['dielec']

    num_conf_rdkit: int = 200
    num_conf_TD: int = 200
    E_avg_proton: float=-275.755
    pKa_EXP: float= 24.88
    Solvent: str="DMSO"
    dielectric_value = 46.826
    
    
    output_dir = f"{index}diel{dielectric_value}"
    os.makedirs(output_dir, exist_ok=True)
    
    temp_output_notebook_1 = 'pka_pipeline_TD_output.ipynb'
    final_output_notebook_1 = os.path.join(output_dir, temp_output_notebook_1)
    
    temp_output_notebook_2 = 'full_pipeline_pka_rdkit_TD_output.ipynb'
    final_output_notebook_2 = os.path.join(output_dir, temp_output_notebook_2)
    
    try:
        subprocess.run(
            f"source /opt/conda/etc/profile.d/conda.sh && conda activate torsional_diffusion && "
            f"papermill pka_pipeline_TD.ipynb {temp_output_notebook_1} "
            f"--log-output -p inp_smiles '{inp_smiles}' -p inp_out_path '{output_dir}' "
            f"-p num_conf_TD {num_conf_TD} -k torsional_diffusion",
            shell=True,
            check=True,
            executable="/bin/bash"
        )
        shutil.move(temp_output_notebook_1, final_output_notebook_1)

        subprocess.run(
            f"source /opt/conda/etc/profile.d/conda.sh && conda activate base && "
            f"papermill full_pipeline_pka_rdkit_TD.ipynb {temp_output_notebook_2} "
            f"--log-output -p inp_smiles '{inp_smiles}' -p output_dir '{output_dir}' "
            f"-p pKa_EXP {pKa_EXP} -p E_avg_proton {E_avg_proton} "
            f"-p num_conf_rdkit {num_conf_rdkit} -p dielectric_value {dielectric_value} -k python3",
            shell=True,
            check=True,
            executable="/bin/bash"
        )
        shutil.move(temp_output_notebook_2, final_output_notebook_2)
        
        
    except subprocess.CalledProcessError as e:
        print(f"❌ Error processing row {index}: {e}")
# Out:
# Current Directory: /work
# Input Notebook:  pka_pipeline_TD.ipynb
# Output Notebook: pka_pipeline_TD_output.ipynb
# Passed unknown parameter: inp_smiles
# Passed unknown parameter: inp_out_path
# Passed unknown parameter: num_conf
# Input notebook does not contain a cell with tag 'parameters'
# Executing notebook with kernel: torsional_diffusion
# Executing Cell 1---------------------------------------
# Ending Cell 1------------------------------------------
# Executing Cell 2---------------------------------------
# /work/0diel46.826
#
# Ending Cell 2------------------------------------------
# Executing Cell 3---------------------------------------
# CSV file 'isomeric_smi_inp.csv' created with exact format!
#
# Ending Cell 3------------------------------------------
# Executing Cell 4---------------------------------------
# Ending Cell 4------------------------------------------
# ❌ Error processing row 0: Command 'source /opt/conda/etc/profile.d/conda.sh && conda activate torsional_diffusion && papermill pka_pipeline_TD.ipynb pka_pipeline_TD_output.ipynb --log-output -p inp_smiles 'O=C(O)/C=C/C(=O)O' -p inp_out_path '0diel46.826' -p num_conf 200 -k torsional_diffusion' returned non-zero exit status 1.
# Traceback (most recent call last):
#   File "/opt/conda/bin/papermill", line 8, in <module>
#     sys.exit(papermill())
#   File "/opt/conda/lib/python3.9/site-packages/click/core.py", line 1161, in __call__
#     return self.main(*args, **kwargs)
#   File "/opt/conda/lib/python3.9/site-packages/click/core.py", line 1082, in main
#     rv = self.invoke(ctx)
#   File "/opt/conda/lib/python3.9/site-packages/click/core.py", line 1443, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/opt/conda/lib/python3.9/site-packages/click/core.py", line 788, in invoke
#     return __callback(*args, **kwargs)
#   File "/opt/conda/lib/python3.9/site-packages/click/decorators.py", line 33, in new_func
#     return f(get_current_context(), *args, **kwargs)
#   File "/opt/conda/lib/python3.9/site-packages/papermill/cli.py", line 235, in papermill
#     execute_notebook(
#   File "/opt/conda/lib/python3.9/site-packages/papermill/execute.py", line 131, in execute_notebook
#     raise_for_execution_errors(nb, output_path)
#   File "/opt/conda/lib/python3.9/site-packages/papermill/execute.py", line 251, in raise_for_execution_errors
#     raise error
# papermill.exceptions.PapermillExecutionError:
# ---------------------------------------------------------------------------
# Exception encountered at "In [4]":
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 16
#       8 out_prefix = "conformers_TD"
#       9 #num_conf_TD= 200
#      10
#      11 # Generate conformers
#      12 subprocess.run([
#      13     "python", "/app/torsional-diffusion-master/generate_confs.py",
#      14     "--model_dir", "/app/TD-trained_models/drugs_default/",
#      15     "--out", f"{inp_out_path}/{out_prefix}.pkl",
# ---> 16     "--test_csv", f"{inp_out_path}/{csv_file_name}.csv",
#      17     "--inference_steps", "20",
#      18     "--confs_per_mol", f"{num_conf_TD}",
#      19     "--tqdm", "--batch_size", "64", "--post_mmff"
#      20 ], check=True)
#      22 # Convert to SDF
#      23 subprocess.run([
#      24     "python", "/app/pkl_to_sdf.py",
#      25     f"{inp_out_path}/{out_prefix}.pkl",
#      26     f"{inp_out_path}/{out_prefix}.sdf"
#      27 ], check=True)
#
# NameError: name 'csv_file_name' is not defined
