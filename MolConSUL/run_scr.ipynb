# %%
import pandas as pd
import subprocess
import os
import shutil

os.chdir('/work')
print("Current Directory:", os.getcwd())

df = pd.read_csv('selected_smiles_solv_pka1.csv')

for index, row in df.iterrows():
    print(index, row)
    inp_smiles = row['smiles']
    #pKa_EXP = row['exp_pka']
    #dielectric_value = row['dielec']

    num_conf_rdkit: int = 200
    num_conf_TD: int = 200
    E_avg_proton: float=-275.755
    pKa_EXP: float= 24.88
    Solvent: str="DMSO"
    dielectric_value = 46.826
    
    
    output_dir = row['id']
    os.makedirs(output_dir, exist_ok=True)
    
    temp_output_notebook_1 = 'full_pipeline_pka_v0.3_output.ipynb'
    final_output_notebook_1 = os.path.join(output_dir, temp_output_notebook_1)
    
    
    try:
        subprocess.run(
            f"source /opt/conda/etc/profile.d/conda.sh && conda activate base && "
            f"papermill full_pipeline_pka_v0.3.ipynb {temp_output_notebook_1} "
            f"--log-output -p inp_smiles '{inp_smiles}' -p output_dir '{output_dir}' "
            f"-p pKa_EXP {pKa_EXP} -p E_avg_proton {E_avg_proton} "
            f"-p num_conf_rdkit {num_conf_rdkit} -p dielectric_value {dielectric_value} -k python3",
            shell=True,
            check=True,
            executable="/bin/bash"
        )
        shutil.move(temp_output_notebook_1, final_output_notebook_1)
        
        
    except subprocess.CalledProcessError as e:
        print(f"❌ Error processing row {index}: {e}")
# Out:
# Current Directory: /work
# 0 id             M2
# smiles    NC(N)=O
# Name: 0, dtype: object
# Input Notebook:  full_pipeline_pka_v0.2.ipynb
# Output Notebook: full_pipeline_pka_v0.2_output.ipynb
# Passed unknown parameter: inp_smiles
# Passed unknown parameter: output_dir
# Passed unknown parameter: pKa_EXP
# Passed unknown parameter: E_avg_proton
# Passed unknown parameter: num_conf_rdkit
# Passed unknown parameter: dielectric_value
# Input notebook does not contain a cell with tag 'parameters'
# Executing notebook with kernel: python3
# Executing Cell 1---------------------------------------
# Ending Cell 1------------------------------------------
# Executing Cell 2---------------------------------------
# Ending Cell 2------------------------------------------
# Executing Cell 3---------------------------------------
# Ending Cell 3------------------------------------------
# Executing Cell 4---------------------------------------
# ...
